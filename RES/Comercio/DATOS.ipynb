# %%
import sys
from pandas import read_csv
sys.path.append(r'C:\Users\luisc\OneDrive\PIAV')
import importlib, funciones
importlib.reload(funciones)
from funciones import descargar_todo
gats = ['0201', '0202']
cmt = '0201,0202'
resultados = descargar_todo(
    hs_codes_gats=gats,
    cmd_code_comtrade=cmt,
    ruta_gats=r'C:\Users\luisc\OneDrive\PIAV\RES\Raw_data',
    ruta_comtrade=r'C:\Users\luisc\OneDrive\PIAV\RES\Comercio'
)
# Out:
# ¿Cómo quieres manejar múltiples códigos HS por año?
#   1 → Sumar todos los códigos
#   2 → Usar solo el código dominante (mayor cantidad)
# ✅ Modo seleccionado: suma
#
#
# ...
# DESCARGANDO GATS + COMTRADE EN PARALELO
# ...
# [GATS] Iniciando USA_MX.csv...
# [GATS] Iniciando MX_USA.csv...
# [GATS] Iniciando USA_CA.csv...
# [GATS] Iniciando CA_USA.csv...
# [Comtrade] Iniciando USA_W...
#   mes 11: 13,920,096
#   mes 11: 53,002
#   mes 11: 6,375,419
#   mes 11: 8,487,014
#   mes 10: 47,102
#   mes 10: 6,449,833
#   mes 10: 8,211,927
#   mes 9: 13,715
#   mes 9: 6,994,998
#   mes 8: 50,195
#   mes 10: 15,405,315
#   mes 9: 7,538,969
#   mes 8: 7,640,789
#   mes 7: 72,577
#   mes 8: 8,186,420
#   mes 9: 13,506,949
#   mes 7: 5,949,997
#   mes 6: 66,010
#   mes 7: 7,448,653
#   mes 8: 14,991,656
#   mes 6: 6,198,686
#   mes 6: 7,639,775
#   mes 7: 14,864,888
#   mes 5: 72,663
#   mes 5: 7,099,702
#   mes 5: 5,999,023
#   mes 6: 15,370,274
#   mes 4: 121,309
#   mes 3: 107,708
#   mes 2: 188,060
# ...
